# %%
# !pip install boto3

# %%
import boto3
import json
import os

# Set your access credentials here if not already set
os.environ["AWS_ACCESS_KEY_ID"] = "AKIAYAJE5LXMT43UOG5P"
os.environ["AWS_SECRET_ACCESS_KEY"] = "G7KkcUo6k3mFjcYORhdcXTQOaCPETsT17ZEeddWx"

bedrock = boto3.client("bedrock", region_name="eu-central-1")
bedrock_runtime = boto3.client("bedrock-runtime", region_name="eu-central-1")

bedrock = boto3.client("bedrock", region_name="eu-central-1")
models = bedrock.list_foundation_models()

for m in models["modelSummaries"]:
    print(m["modelId"], "-", m["providerName"])

kwargs = {
    "modelId": "anthropic.claude-3-sonnet-20240229-v1:0",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps({
        "messages": [
            {"role": "user", "content": "What is the capital of France?"}
        ],
        "max_tokens": 300,
        "anthropic_version": "bedrock-2023-05-31"
    })
}


response = bedrock_runtime.invoke_model(**kwargs)
print(response["body"].read().decode("utf-8"))
# Out:
# amazon.titan-text-express-v1:0:8k - Amazon
# amazon.titan-text-express-v1 - Amazon
# amazon.titan-text-lite-v1:0:4k - Amazon
# amazon.titan-text-lite-v1 - Amazon
# amazon.titan-embed-text-v1:2:8k - Amazon
# amazon.titan-embed-text-v1 - Amazon
# amazon.titan-embed-image-v1:0 - Amazon
# amazon.titan-embed-image-v1 - Amazon
# amazon.titan-embed-text-v2:0 - Amazon
# amazon.rerank-v1:0 - Amazon
# amazon.nova-pro-v1:0 - Amazon
# amazon.nova-lite-v1:0 - Amazon
# amazon.nova-micro-v1:0 - Amazon
# anthropic.claude-instant-v1 - Anthropic
# anthropic.claude-v2:1:18k - Anthropic
# anthropic.claude-v2:1:200k - Anthropic
# anthropic.claude-v2:1 - Anthropic
# anthropic.claude-v2 - Anthropic
# anthropic.claude-3-sonnet-20240229-v1:0 - Anthropic
# anthropic.claude-3-haiku-20240307-v1:0 - Anthropic
# anthropic.claude-3-5-sonnet-20240620-v1:0 - Anthropic
# anthropic.claude-3-7-sonnet-20250219-v1:0 - Anthropic
# anthropic.claude-sonnet-4-20250514-v1:0 - Anthropic
# cohere.embed-english-v3 - Cohere
# ...

# %%
 from IPython.display import Audio

# %%
audio = Audio(filename="videoplayback.weba")
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/webm;base64,..." type="audio/webm" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import boto3

# %%
import os

# %%
os.environ["AWS_ACCESS_KEY_ID"] = "AKIAYAJE5LXMT43UOG5P"
os.environ["AWS_SECRET_ACCESS_KEY"] = "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"

# %%
s3_client = boto3.client("s3", region_name="eu-central-1")

# %%
import os

# %%
os.environ["RESOURCE_S3_BUCKETNAME"] = "corporaidos-audio-uploads-eu"

# %%
bucket_name = os.environ["RESOURCE_S3_BUCKETNAME"]
print(bucket_name)
# Out:
# corporaidos-audio-uploads-eu

# %%
file_name = "videoplayback.weba"

# %%
s3_client.upload_file(file_name, bucket_name, file_name)

# %%
transcribe_client = boto3.client("transcribe", region_name="eu-central-1")

# %%
import uuid

# %%
job_name = "transcription-job-" + str(uuid.uuid4())

# %%
job_name
# Out:
# 'transcription-job-f1e72409-d0c6-46b1-bfc1-a9d690e1dbbd'

# %%
response = transcribe_client.start_transcription_job(
    TranscriptionJobName = job_name,
    Media = {"MediaFileUri": f"s3://{bucket_name}/{file_name}"},
    MediaFormat = "mp3",
    LanguageCode="en-US",
    OutputBucketName = bucket_name,
    Settings = {
        "ShowSpeakerLabels" : True,
        "MaxSpeakerLabels" : 2
    }
)

print("Transcription job started:", job_name)
# Out:
# Transcription job started: transcription-job-f1e72409-d0c6-46b1-bfc1-a9d690e1dbbd

# %%
import time

# %%
while True:
    status = transcribe_client.get_transcription_job(TranscriptionJobName=job_name)
    if status['TranscriptionJob']['TranscriptionJobStatus'] in ['COMPLETED', 'FAILED']:
        break
    time.sleep(2)
print(status['TranscriptionJob']['TranscriptionJobStatus'])
# Out:
# COMPLETED

# %%
import json

# %%
if status["TranscriptionJob"]["TranscriptionJobStatus"] == "COMPLETED":
    transcript_key = f"{job_name}.json"
    transcript_obj = s3_client.get_object(Bucket = bucket_name, Key = transcript_key)
    transcript_text = transcript_obj["Body"].read().decode("utf-8")
    transcript_json = json.loads(transcript_text)

    output_text = ""
    current_speaker = None
    items = transcript_json["results"]["items"]
    for item in items:
        speaker_label = item.get("speaker_label",None)
        content = item["alternatives"][0]["content"]

        if speaker_label is not None and speaker_label != current_speaker:
            current_speaker = speaker_label
            output_text += f"\n{current_speaker}: "

        if item["type"] == "punctuation":
            output_text = output_text.rstrip()
        output_text += f"{content} "

    with open(f"{job_name}.txt", "w")as f:
        f.write(output_text)

# %%
transcript_json
# Out:
# {'jobName': 'transcription-job-f1e72409-d0c6-46b1-bfc1-a9d690e1dbbd',
#  'accountId': '550370106841',
#  'status': 'COMPLETED',
# ...

# %%
print(output_text)
# Out:
# spk_0: Thank you for calling Martha's Florist. How may I assist you?
# spk_1: Hello, I'd like to order flowers and I think you have what I'm looking for.
# spk_0: I'd be happy to take care of your order. May I have your name
# spk_1: please? Randall Thomas.
# spk_0: Randall Thomas, can you spell that for me?
# spk_1: Randall, R A N D A L L Thomas T H O M A N.
# spk_0: Thank you for that information, Randall. May I have your home or office number area code first?
# spk_1: Area code 409 5866. 5088.
# spk_0: That's 409-866-5088. Do you have a fax number or email address?
# spk_1: My email is randall.thomas@gmail.com.
# spk_0: Randall.Thomas@gmail.com. May I have your shipping address?
# spk_1: 6800.
# spk_0: OK.
# spk_1: Maddis Avenue, Beaumont, Texas, zip code is 77706.
# spk_0: Gladys Avenue, Beaumont, Texas, zip code 77706. Thank you for the information. What products were you interested in purchasing?
# spk_1: Red roses probably a dozen.
# ...

# %%
from jinja2 import Template

# %%
bedrock_runtime = boto3.client('bedrock-runtime', region_name='eu-central-1')

# %%
with open(f'{job_name}.txt', "r") as file:
    transcript = file.read()

# %%
# %%writefile prompt_template.txt
# I need to summarize a conversation. The transcript of the
# conversation is between the <data> XML like tags.
#
# <data>
# {{transcript}}
# </data>
#
# The summary must contain a one word sentiment analysis, and
# a list of issues, problems or causes of friction
# during the conversation. The output must be provided in
# JSON format shown in the following example.
#
# Example output:
# {
#     "sentiment": <sentiment>,
#     "issues": [
#         {
#             "topic": <topic>,
#             "summary": <issue_summary>,
#         }
#     ]
# }
#
# Write the JSON output and nothing more.
#
# Here is the JSON output:
# Out:
# Overwriting prompt_template.txt

# %%
with open('prompt_template.txt', "r") as file:
    template_string = file.read()

# %%
data = {
    'transcript' : transcript
}

# %%
template = Template(template_string)

# %%
prompt = template.render(data)

# %%
print(prompt)
# Out:
# I need to summarize a conversation. The transcript of the
# conversation is between the <data> XML like tags.
#
# <data>
#
# spk_0: Thank you for calling Martha's Florist. How may I assist you?
# spk_1: Hello, I'd like to order flowers and I think you have what I'm looking for.
# spk_0: I'd be happy to take care of your order. May I have your name
# spk_1: please? Randall Thomas.
# spk_0: Randall Thomas, can you spell that for me?
# spk_1: Randall, R A N D A L L Thomas T H O M A N.
# spk_0: Thank you for that information, Randall. May I have your home or office number area code first?
# spk_1: Area code 409 5866. 5088.
# spk_0: That's 409-866-5088. Do you have a fax number or email address?
# spk_1: My email is randall.thomas@gmail.com.
# spk_0: Randall.Thomas@gmail.com. May I have your shipping address?
# spk_1: 6800.
# spk_0: OK.
# spk_1: Maddis Avenue, Beaumont, Texas, zip code is 77706.
# ...

# %%
kwargs = {
    "modelId": "amazon.titan-text-express-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps(
        {
            "inputText": prompt,
            "textGenerationConfig": {
                "maxTokenCount": 512,
                "temperature": 0,
                "topP": 0.9
            }
        }
    )
}

# %%
response = bedrock_runtime.invoke_model(**kwargs)

# %%
response_body = json.loads(response.get('body').read())
generation = response_body['results'][0]['outputText']

# %%
print(generation)
# Out:
# {
#     "sentiment": "neutral",
#     "issues": [
#         {
#             "topic": "Ordering flowers",
#             "summary": "The user wants to order flowers"
#         }
#     ]
# }

# %%
import boto3
import json
import os


bedrock = boto3.client('bedrock', region_name="eu-central-1")

# %%
from helpers.CloudWatchHelper import CloudWatch_Helper
cloudwatch = CloudWatch_Helper()

# %%
log_group_name = '/my/amazon/bedrock/logs'

# %%
cloudwatch.create_log_group(log_group_name)
# Out:
# Log group '/my/amazon/bedrock/logs' already exists.

# %%
import os

os.environ["LOGGINGROLEARN"] = "arn:aws:iam::550370106841:role/BedrockLoggingRole"
os.environ["LOGGINGBUCKETNAME"] = "corporaidos-audio-uploads-eu"

# %%
loggingConfig = {
    'cloudWatchConfig': {
        'logGroupName': log_group_name,
        'roleArn': os.environ['LOGGINGROLEARN'],
        'largeDataDeliveryS3Config': {
            'bucketName': os.environ['LOGGINGBUCKETNAME'],
            'keyPrefix': 'amazon_bedrock_large_data_delivery',
        }
    },
    's3Config': {
        'bucketName': os.environ['LOGGINGBUCKETNAME'],
        'keyPrefix': 'amazon_bedrock_logs',
    },
    'textDataDeliveryEnabled': True,
}

# %%
bedrock.put_model_invocation_logging_configuration(loggingConfig=loggingConfig)
# Out:
# {'ResponseMetadata': {'RequestId': 'de3ac27a-0e4a-49c9-bf18-b0679a357340',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Thu, 17 Jul 2025 13:11:51 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'de3ac27a-0e4a-49c9-bf18-b0679a357340'},
#   'RetryAttempts': 0}}

# %%
bedrock.get_model_invocation_logging_configuration()
# Out:
# {'ResponseMetadata': {'RequestId': '4e1df847-4cdd-4193-bcf9-82046d5a4b8f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Thu, 17 Jul 2025 13:11:51 GMT',
#    'content-type': 'application/json',
#    'content-length': '488',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '4e1df847-4cdd-4193-bcf9-82046d5a4b8f'},
#   'RetryAttempts': 0},
#  'loggingConfig': {'cloudWatchConfig': {'logGroupName': '/my/amazon/bedrock/logs',
#    'roleArn': 'arn:aws:iam::550370106841:role/BedrockLoggingRole',
#    'largeDataDeliveryS3Config': {'bucketName': 'corporaidos-audio-uploads-eu',
#     'keyPrefix': 'amazon_bedrock_large_data_delivery'}},
#   's3Config': {'bucketName': 'corporaidos-audio-uploads-eu',
#    'keyPrefix': 'amazon_bedrock_logs'},
#   'textDataDeliveryEnabled': True,
#   'imageDataDeliveryEnabled': True,
#   'embeddingDataDeliveryEnabled': True,
#   'videoDataDeliveryEnabled': True}}

# %%
bedrock_runtime = boto3.client('bedrock-runtime', region_name="eu-central-1")

# %%
prompt = "Write an article about the fictional planet where alens crated there ecology and life evolution."

kwargs = {
    "modelId": "amazon.titan-text-express-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps(
        {
            "inputText": prompt,
            "textGenerationConfig": {
                "maxTokenCount": 512,
                "temperature": 0.7,
                "topP": 0.9
            }
        }
    )
}

response = bedrock_runtime.invoke_model(**kwargs)
response_body = json.loads(response.get('body').read())

generation = response_body['results'][0]['outputText']

print(generation)
# Out:
# A fictional planet, named "Alienia," is a captivating creation of imagination. This planet, located far beyond the confines of our solar system, is home to a diverse range of alien life forms that have evolved over millions of years. The planet's ecology is unique and complex, with a wide variety of habitats, climates, and ecosystems.
#
# One of the most striking features of Alienia is its atmosphere. The planet's atmosphere is rich in oxygen, nitrogen, and other gases that are essential for life. However, it also contains trace amounts of sulfur and carbon dioxide, which make it a hostile environment for some life forms. This has led to the development of unique adaptations among the alien life forms, such as the ability to breathe underwater or survive in extreme temperatures.
#
# ...

# %%
cloudwatch.print_recent_logs(log_group_name)
# Out:
# {"timestamp":"2025-07-17T13:11:28Z","accountId":"550370106841","identity":{"arn":"arn:aws:iam::550370106841:root"},"region":"eu-central-1","requestId":"72531db2-452d-4ab2-af1d-df7765a40b67","operation":"InvokeModel","modelId":"anthropic.claude-3-sonnet-20240229-v1:0","input":{"inputContentType":"application/json","inputBodyJson":{"messages":[{"role":"user","content":"What is the capital of France?"}],"max_tokens":300,"anthropic_version":"bedrock-2023-05-31"},"inputTokenCount":14},"output":{"outputContentType":"application/json","outputBodyJson":{"id":"msg_bdrk_012458nTh1dqvTNe8bXdSyj6","type":"message","role":"assistant","model":"claude-3-sonnet-20240229","content":[{"type":"text","text":"The capital of France is Paris."}],"stop_reason":"end_turn","stop_sequence":null,"usage":{"input_tokens":14,"output_tokens":10}},"outputTokenCount":10},"schemaType":"ModelInvocationLog","schemaVersion":"1.0"}
# ...
